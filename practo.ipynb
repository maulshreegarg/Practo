# %% [markdown]
# <a href="https://colab.research.google.com/github/maulshreegarg/bookstore_management/blob/main/practo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import pandas as pd
data=pd.read_csv("/content/doctor.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1695139939-1  https://www.practo.com/search/doctors?results_...
# 1      1695139951-2  https://www.practo.com/search/doctors?results_...
# 2      1695139962-3  https://www.practo.com/search/doctors?results_...
# 3      1695139974-4  https://www.practo.com/search/doctors?results_...
# 4      1695139987-5  https://www.practo.com/search/doctors?results_...
#
#                 link2                                         link2-href  \
# 0         Dr. Kavitha  https://www.practo.com/bangalore/doctor/dr-kav...
# 1     Dr. Ameena Meah  https://www.practo.com/bangalore/doctor/ameena...
# 2  Dr. Rakshith B Das  https://www.practo.com/bangalore/doctor/dr-rak...
# 3         Dr. Mohit J  https://www.practo.com/bangalore/doctor/dr-moh...
# 4        Dr. Renuka C  https://www.practo.com/bangalore/doctor/dr-ren...
#
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality price                       verified  \
# 0   General Physician  ₹750  Medical Registration Verified
# 1  General Physician,  ₹500  Medical Registration Verified
# 2   General Physician  ₹200  Medical Registration Verified
# 3   General Physician  ₹200  Medical Registration Verified
# 4   General Physician  ₹200  Medical Registration Verified
#
#                                           yearsofexp
# 0                        20 Years Experience Overall
# 1  12 Years Experience Overall  (8 years as speci...
# 2                         3 Years Experience Overall
# 3                         3 Years Experience Overall
# 4                         4 Years Experience Overall

# %%
df=df.drop(['web-scraper-order','web-scraper-start-url','link2','link2-href'],axis=1)
df.head()
# Out:
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality price                       verified  \
# 0   General Physician  ₹750  Medical Registration Verified
# 1  General Physician,  ₹500  Medical Registration Verified
# 2   General Physician  ₹200  Medical Registration Verified
# 3   General Physician  ₹200  Medical Registration Verified
# 4   General Physician  ₹200  Medical Registration Verified
#
#                                           yearsofexp
# 0                        20 Years Experience Overall
# 1  12 Years Experience Overall  (8 years as speci...
# 2                         3 Years Experience Overall
# 3                         3 Years Experience Overall
# 4                         4 Years Experience Overall

# %%
df.head()
print(pd.isna(df))
df.info()
# Out:
#       name  degree  speciality  price  verified  yearsofexp
# 0    False   False       False  False     False       False
# 1    False   False       False  False     False       False
# 2    False   False       False  False     False       False
# 3    False   False       False  False     False       False
# 4    False   False       False  False     False       False
# ..     ...     ...         ...    ...       ...         ...
# 234  False   False       False  False     False       False
# 235  False   False       False  False     False       False
# 236  False   False       False  False     False       False
# 237  False   False       False  False     False       False
# 238  False   False       False  False     False       False
#
# [239 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        239 non-null    object
#  1   degree      239 non-null    object
#  2   speciality  239 non-null    object
#  3   price       239 non-null    object
#  4   verified    239 non-null    object
#  5   yearsofexp  239 non-null    object
# dtypes: object(6)
# memory usage: 11.3+ KB

# %%
df.shape
# Out:
# (239, 6)

# %%
df["price"]=df["price"].str.replace('₹','')

# %%
df["price"]=df["price"].str.replace('fee','')

# %%
df['price']=pd.to_numeric(df["price"])

# %%
df['verifiedbool']=df["verified"]=="Medical Registration Verified"

# %%
df[['years_of_experience', 'years_as_spec']] = df['yearsofexp'].str.split('(', 1, expand=True)
# Out:
# <ipython-input-163-0244f04a7823>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['years_of_experience', 'years_as_spec']] = df['yearsofexp'].str.split('(', 1, expand=True)

# %%
df.head()
# Out:
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality  price                       verified  \
# 0   General Physician    750  Medical Registration Verified
# 1  General Physician,    500  Medical Registration Verified
# 2   General Physician    200  Medical Registration Verified
# 3   General Physician    200  Medical Registration Verified
# 4   General Physician    200  Medical Registration Verified
#
#                                           yearsofexp  verifiedbool  \
# 0                        20 Years Experience Overall          True
# 1  12 Years Experience Overall  (8 years as speci...          True
# 2                         3 Years Experience Overall          True
# 3                         3 Years Experience Overall          True
# 4                         4 Years Experience Overall          True
#
#              years_of_experience           years_as_spec
# 0    20 Years Experience Overall                    None
# 1  12 Years Experience Overall    8 years as specialist)
# 2     3 Years Experience Overall                    None
# 3     3 Years Experience Overall                    None
# 4     4 Years Experience Overall                    None

# %%
df["years_of_experience"]=df["years_of_experience"].str.replace('Years Experience Overall','')

# %%
df["years_of_experience"]=df["years_of_experience"].str.strip()

df.head()
# Out:
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality  price                       verified  \
# 0   General Physician    750  Medical Registration Verified
# 1  General Physician,    500  Medical Registration Verified
# 2   General Physician    200  Medical Registration Verified
# 3   General Physician    200  Medical Registration Verified
# 4   General Physician    200  Medical Registration Verified
#
#                                           yearsofexp  verifiedbool  \
# 0                        20 Years Experience Overall          True
# 1  12 Years Experience Overall  (8 years as speci...          True
# 2                         3 Years Experience Overall          True
# 3                         3 Years Experience Overall          True
# 4                         4 Years Experience Overall          True
#
#   years_of_experience           years_as_spec
# 0                  20                    None
# 1                  12  8 years as specialist)
# 2                   3                    None
# 3                   3                    None
# 4                   4                    None

# %%
df["years_of_experience"]=pd.to_numeric(df["years_of_experience"])

# %%
df['years_as_spec']=df['years_as_spec'].str.replace(' years as specialist','')

# %%
df.head()
# Out:
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality  price                       verified  \
# 0   General Physician    750  Medical Registration Verified
# 1  General Physician,    500  Medical Registration Verified
# 2   General Physician    200  Medical Registration Verified
# 3   General Physician    200  Medical Registration Verified
# 4   General Physician    200  Medical Registration Verified
#
#                                           yearsofexp  verifiedbool  \
# 0                        20 Years Experience Overall          True
# 1  12 Years Experience Overall  (8 years as speci...          True
# 2                         3 Years Experience Overall          True
# 3                         3 Years Experience Overall          True
# 4                         4 Years Experience Overall          True
#
#    years_of_experience years_as_spec
# 0                   20          None
# 1                   12            8)
# 2                    3          None
# 3                    3          None
# 4                    4          None

# %%
df['years_as_spec']=df['years_as_spec'].str.replace('\)','')
# Out:
# <ipython-input-170-4a8f275bf412>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['years_as_spec']=df['years_as_spec'].str.replace('\)','')

# %%
df['years_as_spec']=df['years_as_spec'].str.strip()
df['years_as_spec']=pd.to_numeric(df['years_as_spec'])

df.head()
# Out:
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality  price                       verified  \
# 0   General Physician    750  Medical Registration Verified
# 1  General Physician,    500  Medical Registration Verified
# 2   General Physician    200  Medical Registration Verified
# 3   General Physician    200  Medical Registration Verified
# 4   General Physician    200  Medical Registration Verified
#
#                                           yearsofexp  verifiedbool  \
# 0                        20 Years Experience Overall          True
# 1  12 Years Experience Overall  (8 years as speci...          True
# 2                         3 Years Experience Overall          True
# 3                         3 Years Experience Overall          True
# 4                         4 Years Experience Overall          True
#
#    years_of_experience  years_as_spec
# 0                   20            NaN
# 1                   12            8.0
# 2                    3            NaN
# 3                    3            NaN
# 4                    4            NaN

# %%
df['years_as_spec'] = df['years_as_spec'].fillna(0)

# %%
df["years_as_spec"]=df["years_as_spec"].astype(int)
df=df.drop(["yearsofexp"],axis=1)
df.head()
# Out:
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#            speciality  price                       verified  verifiedbool  \
# 0   General Physician    750  Medical Registration Verified          True
# 1  General Physician,    500  Medical Registration Verified          True
# 2   General Physician    200  Medical Registration Verified          True
# 3   General Physician    200  Medical Registration Verified          True
# 4   General Physician    200  Medical Registration Verified          True
#
#    years_of_experience  years_as_spec
# 0                   20              0
# 1                   12              8
# 2                    3              0
# 3                    3              0
# 4                    4              0

# %%
df["speciality"]=df["speciality"].str.replace(',','')

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 239 non-null    object
#  1   degree               239 non-null    object
#  2   speciality           239 non-null    object
#  3   price                239 non-null    int64
#  4   verified             239 non-null    object
#  5   verifiedbool         239 non-null    bool
#  6   years_of_experience  239 non-null    int64
#  7   years_as_spec        239 non-null    int64
# dtypes: bool(1), int64(3), object(4)
# memory usage: 13.4+ KB
#                  name                                             degree  \
# 0         Dr. Kavitha                        MBBS, DNB - Family Medicine
# 1     Dr. Ameena Meah  MBBS, MD - General Medicine, DNB - General Med...
# 2  Dr. Rakshith B Das                                               MBBS
# 3         Dr. Mohit J                                               MBBS
# 4        Dr. Renuka C                                               MBBS
#
#           speciality  price                       verified  verifiedbool  \
# 0  General Physician    750  Medical Registration Verified          True
# 1  General Physician    500  Medical Registration Verified          True
# 2  General Physician    200  Medical Registration Verified          True
# 3  General Physician    200  Medical Registration Verified          True
# 4  General Physician    200  Medical Registration Verified          True
#
#    years_of_experience  years_as_spec
# 0                   20              0
# 1                   12              8
# 2                    3              0
# 3                    3              0
# 4                    4              0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['years_of_experience'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['years_as_spec'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['years_of_experience'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['years_as_spec'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_6, *['name'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_7, *['degree'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['price', 'years_of_experience'], ['years_of_experience', 'years_as_spec']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_9, *['name', 'degree'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_10, *['price', 'name'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_11, *['price', 'degree'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_12, *['years_of_experience', 'name'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_13, *['years_of_experience', 'degree'], **{'inner': 'stick'})
# chart
